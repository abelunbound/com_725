# %%
## General Notes

# %%
#### All dependencies

## Data collection and visualisation

import yfinance as yf
import pandas as pd
from pandas import  read_csv
from pandas import set_option
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib.dates as mpl_dates


import plotly.offline as py
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

plt.style.use('seaborn-darkgrid')

## Prediction Engine, Featuring Engineering, Model Evaluation
import warnings
warnings.filterwarnings('ignore')
import os
# import pandas as pd
import numpy as np
import math
import datetime as dt
# import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler

from itertools import product
import statsmodels.api as sm

import tensorflow as tf

from keras.models import Sequential
from keras.models import load_model
from keras.layers import Activation, Dense, Dropout
from keras.layers import LSTM

from itertools import cycle
# import plotly.offline as py
# import plotly.graph_objects as go
# import plotly.express as px
# from plotly.subplots import make_subplots

# plt.style.use('seaborn-darkgrid')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\PycharmProjects\venv\lib\site-packages\tensorflow\python\pywrap_tensorflow.py:62, in <module>
#      61 try:
# ---> 62   from tensorflow.python._pywrap_tensorflow_internal import *
#      63 # This try catch logic is because there is no bazel equivalent for py_extension.
#      64 # Externally in opensource we must enable exceptions to load the shared object
#      65 # by exposing the PyInit symbols with pybind. This error will only be
#      66 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      67
#      68 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: The paging file is too small for this operation to complete.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Input In [4], in <cell line: 38>()
#      35 from itertools import product
#      36 import statsmodels.api as sm
# ---> 38 import tensorflow as tf
#      40 from keras.models import Sequential
#      41 from keras.models import load_model
#
# File ~\PycharmProjects\venv\lib\site-packages\tensorflow\__init__.py:37, in <module>
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\PycharmProjects\venv\lib\site-packages\tensorflow\python\__init__.py:36, in <module>
#      27 import traceback
#      29 # We aim to keep this file minimal and ideally remove completely.
#      30 # If you are adding a new file with @tf_export decorators,
#      31 # import it in modules_with_exports.py instead.
#      32
#      33 # go/tf-wildcard-import
#      34 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
# ---> 36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#
# File ~\PycharmProjects\venv\lib\site-packages\tensorflow\python\pywrap_tensorflow.py:77, in <module>
#      75     sys.setdlopenflags(_default_dlopen_flags)
#      76 except ImportError:
# ---> 77   raise ImportError(
#      78       f'{traceback.format_exc()}'
#      79       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      80       f'See https://www.tensorflow.org/install/errors '
#      81       f'for some common causes and solutions.\n'
#      82       f'If you need help, create an issue '
#      83       f'at https://github.com/tensorflow/tensorflow/issues '
#      84       f'and include the entire stack trace above this error message.')
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\User\PycharmProjects\venv\lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 62, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: The paging file is too small for this operation to complete.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.

# %%
#### Data Engineering


df = pd.DataFrame()

crypto_ticker = ['BTC', 'ETH', 'USDT']


#Extract data for each of the 10 coins from YahooFinance! using a For loop.
for each_crypto_ticker in crypto_ticker:

    each_crypto_ticker_index = crypto_ticker.index(each_crypto_ticker)
    crypto_data = yf.Ticker(f"{each_crypto_ticker}-USD").history(start='2015-01-01', end='2022-07-31', interval='1d')
    crypto_dataframe = pd.DataFrame(crypto_data)
    crypto_dataframe['crypto_ticker'] = each_crypto_ticker
    df = pd.concat([df, crypto_dataframe])


set_option('display.width', 500)
df = df.rename_axis('cryptodate').reset_index()

# ###Convert data to CSV and store it
df.to_csv("soligencecryptodata_withdate.csv")

###Extract data to different dataframes to simplify data understanding for each cryptocurrency
BTC = df.loc[df['crypto_ticker'] == 'BTC']
ETH = df.loc[df['crypto_ticker'] == 'ETH']
USDT = df.loc[df['crypto_ticker'] == 'USDT']


df
# Out:
#      cryptodate        Open        High         Low       Close       Volume  Dividends  Stock Splits crypto_ticker
# 0    2015-01-01  320.434998  320.434998  314.002991  314.248993      8036550          0             0           BTC
# 1    2015-01-02  314.079010  315.838989  313.565002  315.032013      7860650          0             0           BTC
# 2    2015-01-03  314.846008  315.149994  281.082001  281.082001     33054400          0             0           BTC
# 3    2015-01-04  281.145996  287.230011  257.612000  264.195007     55629100          0             0           BTC
# 4    2015-01-05  265.084015  278.341003  265.084015  274.473999     43962800          0             0           BTC
# ...         ...         ...         ...         ...         ...          ...        ...           ...           ...
# 6213 2022-07-26    1.000067    1.000128    0.999996    1.000047  48266723630          0             0          USDT
# 6214 2022-07-27    1.000048    1.000328    0.999980    1.000274  60104591185          0             0          USDT
# 6215 2022-07-28    1.000288    1.000360    1.000123    1.000200  75754591120          0             0          USDT
# 6216 2022-07-29    1.000205    1.000346    1.000169    1.000311  72013108986          0             0          USDT
# 6217 2022-07-30    1.000310    1.000352    1.000217    1.000289  57489826931          0             0          USDT
#
# [6218 rows x 9 columns]

# %%
prepared_data = pd.read_csv('combined_data.csv', encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 prepared_data = pd.read_csv('combined_data.csv', encoding='latin-1')
#
# NameError: name 'pd' is not defined

# %%
prepared_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 prepared_data
#
# NameError: name 'prepared_data' is not defined

# %%
# Obtain data for feature
close_price = BTC.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits', 'crypto_ticker', 'cryptodate'])

# Split data into training and test data 80% for training data and 20% for test data
prediction_period = 554 # In days

training_data = close_price[:len(close_price)-prediction_period].values.reshape(-1,1)
testing_data = close_price[len(close_price)-prediction_period:].values.reshape(-1,1)

# Scale the data
scaler_train = MinMaxScaler(feature_range=(0,1))
scaled_train = scaler_train.fit_transform(training_data)


scaler_test = MinMaxScaler(feature_range=(0,1))
scaled_test = scaler_test.fit_transform(testing_data)
# close_price

# %%
scaled_test
# Out:
# array([[0.26879957],
#        [0.27336682],
#        [0.27495312],
#        [0.27914386],
#        [0.23512041],
#        [0.29760448],
#        [0.31511845],
#        [0.31415318],
#        [0.29035949],
#        [0.29906852],
#        [0.33971005],
#        [0.38011858],
#        [0.36887177],
#        [0.39396471],
#        [0.41706918],
#        [0.40960108],
#        [0.55982035],
#        [0.56568329],
#        [0.53349074],
#        [0.59510142],
#        [0.58677007],
#        [0.57854468],
#        [0.61174345],
#        [0.59583731],
#        [0.62168352],
#        [0.68242886],
#        [0.67276421],
#        [0.75944611],
#        [0.76380019],
#        [0.7934696 ],
#        [0.72482529],
#        [0.61395022],
#        [0.63209484],
#        [0.57830443],
#        [0.56277194],
#        [0.55965533],
#        [0.5380137 ],
#        [0.63056876],
#        [0.60477525],
#        [0.64925084],
#        [0.60852772],
#        [0.61606929],
#        [0.61576193],
#        [0.66301934],
#        [0.68443745],
#        [0.73752987],
#        [0.76192644],
#        [0.7989316 ],
#        [0.78918826],
#        [0.86974566],
#        [0.82977033],
#        [0.75983884],
#        [0.77832943],
#        [0.82088405],
#        [0.80003977],
#        [0.81008588],
#        [0.809406  ],
#        [0.79312925],
#        [0.73145412],
#        [0.73577553],
#        [0.69530771],
#        [0.67326603],
#        [0.74398097],
#        [0.76120472],
#        [0.7607358 ],
#        [0.79780034],
#        [0.82184795],
#        [0.82187145],
#        [0.82551675],
#        [0.83145926],
#        [0.79478672],
#        [0.81857011],
#        [0.82473549],
#        [0.80690781],
#        [0.76275831],
#        [0.80961833],
#        [0.80799216],
#        [0.8398821 ],
#        [0.84836279],
#        [0.84194637],
#        [0.91630403],
#        [0.90819346],
#        [0.9124019 ],
#        [0.87653677],
#        [0.85822609],
#        [0.76620319],
#        [0.75607083],
#        [0.77149366],
#        [0.71862065],
#        [0.67446303],
#        [0.660691  ],
#        [0.63921205],
#        [0.61765426],
#        [0.72100306],
#        [0.74183478],
#        [0.73754194],
#        [0.71139127],
#        [0.79779986],
#        [0.7994039 ],
#        [0.77474905],
#        [0.78647355],
#        [0.70682744],
#        [0.79108156],
#        [0.76991761],
#        [0.78968904],
#        [0.81950159],
#        [0.80773083],
#        [0.75886246],
#        [0.7762629 ],
#        [0.62066731],
#        [0.63231851],
#        [0.63570361],
#        [0.57143173],
#        [0.56516738],
#        [0.50505212],
#        [0.49211453],
#        [0.37044491],
#        [0.44831021],
#        [0.37667056],
#        [0.38144801],
#        [0.32447382],
#        [0.40553385],
#        [0.39927714],
#        [0.41764978],
#        [0.39999283],
#        [0.34356834],
#        [0.32129115],
#        [0.34316716],
#        [0.37725067],
#        [0.36390483],
#        [0.38224199],
#        [0.41589005],
#        [0.36821964],
#        [0.34056832],
#        [0.34696228],
#        [0.29955321],
#        [0.29773909],
#        [0.37750332],
#        [0.36426883],
#        [0.37728245],
#        [0.34057982],
#        [0.41360564],
#        [0.43668774],
#        [0.44055583],
#        [0.39814097],
#        [0.39209435],
#        [0.34541472],
#        [0.3418848 ],
#        [0.34358258],
#        [0.26074692],
#        [0.27782171],
#        [0.30289663],
#        [0.32224629],
#        [0.25994538],
#        [0.27124317],
#        [0.32198278],
#        [0.31754793],
#        [0.34707348],
#        [0.33004042],
#        [0.29978823],
#        [0.30648103],
#        [0.32237213],
#        [0.33512691],
#        [0.3033699 ],
#        [0.3134461 ],
#        [0.30562172],
#        [0.28547808],
#        [0.30444113],
#        [0.29872544],
#        [0.31354892],
#        [0.29121405],
#        [0.28186637],
#        [0.28434473],
#        [0.26288985],
#        [0.25549134],
#        [0.25778858],
#        [0.26322106],
#        [0.24305638],
#        [0.22224276],
#        [0.26968631],
#        [0.27385553],
#        [0.29998254],
#        [0.31462531],
#        [0.33641234],
#        [0.37734706],
#        [0.41997201],
#        [0.43210331],
#        [0.4323611 ],
#        [0.47823468],
#        [0.46568346],
#        [0.43167052],
#        [0.41574956],
#        [0.39414333],
#        [0.4269868 ],
#        [0.45009843],
#        [0.49020096],
#        [0.5260265 ],
#        [0.51041999],
#        [0.56330007],
#        [0.54722625],
#        [0.5474035 ],
#        [0.52340006],
#        [0.59271185],
#        [0.57836815],
#        [0.57733948],
#        [0.555866  ],
#        [0.52890108],
#        [0.5310809 ],
#        [0.57055407],
#        [0.62455287],
#        [0.61562   ],
#        [0.62419193],
#        [0.62881602],
#        [0.59091567],
#        [0.61675899],
#        [0.57518115],
#        [0.61877506],
#        [0.61555636],
#        [0.61406158],
#        [0.57750385],
#        [0.57980468],
#        [0.61441576],
#        [0.62431696],
#        [0.63868697],
#        [0.63702371],
#        [0.67428047],
#        [0.69240899],
#        [0.572481  ],
#        [0.55765607],
#        [0.56383601],
#        [0.53278479],
#        [0.53932551],
#        [0.55707684],
#        [0.53441538],
#        [0.57827643],
#        [0.60060132],
#        [0.59250668],
#        [0.58188158],
#        [0.60270261],
#        [0.5817312 ],
#        [0.49076329],
#        [0.44647573],
#        [0.50581415],
#        [0.53301523],
#        [0.49067986],
#        [0.48814313],
#        [0.49827605],
#        [0.47823846],
#        [0.4534968 ],
#        [0.46440986],
#        [0.51027122],
#        [0.59937769],
#        [0.5910263 ],
#        [0.60108754],
#        [0.61989217],
#        [0.66936591],
#        [0.74859766],
#        [0.71655871],
#        [0.71989272],
#        [0.74049811],
#        [0.73644769],
#        [0.79233351],
#        [0.76259603],
#        [0.79060966],
#        [0.78897062],
#        [0.87697262],
#        [0.86251781],
#        [0.87614188],
#        [0.88587347],
#        [0.93192809],
#        [0.96757943],
#        [0.88966537],
#        [0.85840004],
#        [0.87284625],
#        [0.86331404],
#        [0.90675428],
#        [0.85163427],
#        [0.81288169],
#        [0.85695555],
#        [0.89003187],
#        [0.88304652],
#        [0.87130843],
#        [0.86482941],
#        [0.91059735],
#        [0.90531703],
#        [0.87405355],
#        [0.86732728],
#        [0.87560352],
#        [0.91266919],
#        [1.        ],
#        [0.98774439],
#        [0.94703109],
#        [0.94609864],
#        [0.92974369],
#        [0.93620283],
#        [0.95674514],
#        [0.91742483],
#        [0.84746228],
#        [0.85172117],
#        [0.78115614],
#        [0.80540868],
#        [0.83790392],
#        [0.81799177],
#        [0.767709  ],
#        [0.79406959],
#        [0.76752643],
#        [0.78800574],
#        [0.71169316],
#        [0.73734369],
#        [0.78746562],
#        [0.79896137],
#        [0.78245974],
#        [0.78708191],
#        [0.77159222],
#        [0.71227979],
#        [0.62170066],
#        [0.62516404],
#        [0.65016502],
#        [0.65258445],
#        [0.64856195],
#        [0.59021543],
#        [0.58138281],
#        [0.62503346],
#        [0.6401898 ],
#        [0.57096401],
#        [0.56839244],
#        [0.61543937],
#        [0.59007752],
#        [0.55993734],
#        [0.57325647],
#        [0.57033651],
#        [0.5739053 ],
#        [0.61626102],
#        [0.60991485],
#        [0.65432398],
#        [0.65509961],
#        [0.64701841],
#        [0.65483844],
#        [0.65135543],
#        [0.58850035],
#        [0.56493365],
#        [0.58004026],
#        [0.5620857 ],
#        [0.59051804],
#        [0.58348201],
#        [0.56520978],
#        [0.5536639 ],
#        [0.50570079],
#        [0.49729541],
#        [0.46427678],
#        [0.46790278],
#        [0.47156216],
#        [0.46970137],
#        [0.48853987],
#        [0.51352991],
#        [0.48556793],
#        [0.4960342 ],
#        [0.49763463],
#        [0.49632627],
#        [0.47854373],
#        [0.48112013],
#        [0.46811672],
#        [0.44620265],
#        [0.35921661],
#        [0.32982237],
#        [0.35549849],
#        [0.36327459],
#        [0.36944721],
#        [0.36734867],
#        [0.37324193],
#        [0.38655004],
#        [0.39383847],
#        [0.38929508],
#        [0.40094354],
#        [0.40630199],
#        [0.36942621],
#        [0.37357906],
#        [0.46310215],
#        [0.46187225],
#        [0.48187814],
#        [0.51128855],
#        [0.517018  ],
#        [0.52155673],
#        [0.50562065],
#        [0.48178553],
#        [0.47841845],
#        [0.47745133],
#        [0.48547211],
#        [0.52642614],
#        [0.51379269],
#        [0.44326942],
#        [0.43282567],
#        [0.43470376],
#        [0.39987769],
#        [0.37194524],
#        [0.39688379],
#        [0.37650328],
#        [0.39784327],
#        [0.41600237],
#        [0.41375577],
#        [0.38501454],
#        [0.49796081],
#        [0.52188299],
#        [0.51301529],
#        [0.48268877],
#        [0.41442431],
#        [0.4198411 ],
#        [0.39964299],
#        [0.39227015],
#        [0.40617833],
#        [0.47303128],
#        [0.42060064],
#        [0.40736688],
#        [0.40961283],
#        [0.38789572],
#        [0.42532354],
#        [0.41856815],
#        [0.45574991],
#        [0.45178382],
#        [0.46928725],
#        [0.47730996],
#        [0.4578899 ],
#        [0.45439184],
#        [0.48077359],
#        [0.4917758 ],
#        [0.51377362],
#        [0.52176134],
#        [0.52489419],
#        [0.57267386],
#        [0.57900789],
#        [0.58596427],
#        [0.57766204],
#        [0.54627143],
#        [0.56157486],
#        [0.5530743 ],
#        [0.56511605],
#        [0.56859931],
#        [0.54662811],
#        [0.49823896],
#        [0.50435872],
#        [0.47930817],
#        [0.48949316],
#        [0.47766052],
#        [0.42233993],
#        [0.43480732],
#        [0.45621956],
#        [0.4308594 ],
#        [0.44358771],
#        [0.44093102],
#        [0.42635752],
#        [0.44920573],
#        [0.46314078],
#        [0.46049663],
#        [0.44305008],
#        [0.42683883],
#        [0.42161547],
#        [0.4212563 ],
#        [0.44162772],
#        [0.39341172],
#        [0.41655649],
#        [0.42752902],
#        [0.40355325],
#        [0.38511938],
#        [0.40065453],
#        [0.40189522],
#        [0.38585221],
#        [0.42597478],
#        [0.36164351],
#        [0.35063985],
#        [0.33953835],
#        [0.30982236],
#        [0.23232749],
#        [0.24728043],
#        [0.20430235],
#        [0.20659686],
#        [0.21144456],
#        [0.22829679],
#        [0.25309324],
#        [0.22338738],
#        [0.23498262],
#        [0.19985153],
#        [0.2326855 ],
#        [0.20974806],
#        [0.21451614],
#        [0.23287888],
#        [0.2076506 ],
#        [0.21911682],
#        [0.21719661],
#        [0.21111749],
#        [0.19794218],
#        [0.20180066],
#        [0.21479896],
#        [0.26177057],
#        [0.26312837],
#        [0.22207247],
#        [0.23584012],
#        [0.22012209],
#        [0.22276937],
#        [0.22428841],
#        [0.25444359],
#        [0.25001111],
#        [0.23062617],
#        [0.22851785],
#        [0.20733946],
#        [0.19244747],
#        [0.15952906],
#        [0.07146868],
#        [0.06568906],
#        [0.07322877],
#        [0.02809538],
#        [0.02994571],
#        [0.        ],
#        [0.03163037],
#        [0.03258334],
#        [0.03487093],
#        [0.01996711],
#        [0.0426008 ],
#        [0.04560352],
#        [0.05117893],
#        [0.04139415],
#        [0.03538341],
#        [0.02601469],
#        [0.02237691],
#        [0.01580014],
#        [0.00518494],
#        [0.00462651],
#        [0.00575568],
#        [0.02499772],
#        [0.0241502 ],
#        [0.03152686],
#        [0.05396476],
#        [0.05589125],
#        [0.05303002],
#        [0.03795752],
#        [0.01962781],
#        [0.00630848],
#        [0.02460251],
#        [0.03197329],
#        [0.03746068],
#        [0.04475201],
#        [0.03628694],
#        [0.07143368],
#        [0.0900487 ],
#        [0.08680042],
#        [0.08541825],
#        [0.0761565 ],
#        [0.07101738],
#        [0.07397697],
#        [0.04828214],
#        [0.04577031],
#        [0.08059674],
#        [0.09940937],
#        [0.09860084],
#        [0.09554361]])

# %%
#### Feature Engineering


#Create a series of timesteps and observations for X and Y axis for test and training data

def split_x_and_yaxis(dataset, look_back=3):

    dataX, dataY = [], []

    for i in range(len(dataset) - look_back):
        window_size_x = dataset[i:(i + look_back), 0]
        
        dataX.append(window_size_x)
        dataY.append(dataset[i + look_back, 0]) # this is the label or actual y-value
    return np.array(dataX), np.array(dataY)

trainX, trainY = split_x_and_yaxis(scaled_train)
testX, testY = split_x_and_yaxis(scaled_test)



## View shape of the datasets
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)

## Reshape data to 3D Tensors for LSTM for (Samples, timesteps, features) Batch size, timesteps or lookback, target features

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1 ))

print("Shape of trainX: ", trainX.shape)
print("Shape of testX: ", testX.shape)
# Out:
# (2211, 3)
# (2211,)
# (551, 3)
# (551,)
# Shape of trainX:  (2211, 3, 1)
# Shape of testX:  (551, 3, 1)

# %%
trainX
# Out:
# array([[[0.00335174],
#         [0.00337102],
#         [0.00253521]],
#
#        [[0.00337102],
#         [0.00253521],
#         [0.00211947]],
#
#        [[0.00253521],
#         [0.00211947],
#         [0.00237253]],
#
#        ...,
#
#        [[0.87675054],
#         [0.89740064],
#         [0.88360753]],
#
#        [[0.89740064],
#         [0.88360753],
#         [0.87075521]],
#
#        [[0.88360753],
#         [0.87075521],
#         [0.7545044 ]]])

# %%
#### LSTM Prediction Engine

##Create the LSTM Model

regressor = Sequential()
# First Layer
regressor.add(LSTM(units = 128, activation = 'relu',return_sequences=True, input_shape = (trainX.shape[1], trainX.shape[2])))
regressor.add(Dropout(0.2))

# Second Layer
regressor.add(LSTM(units = 64, activation = 'relu',return_sequences=True, input_shape = (trainX.shape[1], trainX.shape[2])))
regressor.add(Dropout(0.2))

# Third Layer
regressor.add(LSTM(units = 64, activation = 'relu',return_sequences=True, input_shape = (trainX.shape[1], trainX.shape[2])))
regressor.add(Dropout(0.2))

# Fourth Layer
regressor.add(LSTM(units = 64, input_shape = (trainX.shape[1], trainX.shape[2])))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 3, 128)            66560
#
#  dropout (Dropout)           (None, 3, 128)            0
#
#  lstm_1 (LSTM)               (None, 3, 64)             49408
#
#  dropout_1 (Dropout)         (None, 3, 64)             0
#
#  lstm_2 (LSTM)               (None, 3, 64)             33024
#
#  dropout_2 (Dropout)         (None, 3, 64)             0
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 182,081
# Trainable params: 182,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
## Compile the LSTM model

from  keras.callbacks import ModelCheckpoint, EarlyStopping

# Compiling the LSTM
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

checkpoint_path = 'new_crypto_model.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                             mode='min')


earlystopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]


history = regressor.fit(trainX, trainY, batch_size = 32, epochs = 150, verbose=1, shuffle=False, validation_data=(testX, testY), callbacks=callbacks)
# Out:
# Epoch 1/150
# 65/70 [==========================>...] - ETA: 0s - loss: 0.0049
# Epoch 1: val_loss improved from inf to 0.10635, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 7s 25ms/step - loss: 0.0109 - val_loss: 0.1064
# Epoch 2/150
# 67/70 [===========================>..] - ETA: 0s - loss: 0.0250
# Epoch 2: val_loss did not improve from 0.10635
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0307 - val_loss: 0.1162
# Epoch 3/150
# 65/70 [==========================>...] - ETA: 0s - loss: 0.0234
# Epoch 3: val_loss did not improve from 0.10635
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0295 - val_loss: 0.1267
# Epoch 4/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0226
# Epoch 4: val_loss improved from 0.10635 to 0.04902, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 1s 13ms/step - loss: 0.0228 - val_loss: 0.0490
# Epoch 5/150
# 68/70 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 5: val_loss improved from 0.04902 to 0.01532, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 1s 12ms/step - loss: 0.0212 - val_loss: 0.0153
# Epoch 6/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0189
# Epoch 6: val_loss did not improve from 0.01532
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0194 - val_loss: 0.1563
# Epoch 7/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 7: val_loss did not improve from 0.01532
# 70/70 [==============================] - 1s 13ms/step - loss: 0.0161 - val_loss: 0.0746
# Epoch 8/150
# 66/70 [===========================>..] - ETA: 0s - loss: 0.0126
# Epoch 8: val_loss improved from 0.01532 to 0.01359, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 1s 15ms/step - loss: 0.0134 - val_loss: 0.0136
# Epoch 9/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 9: val_loss improved from 0.01359 to 0.00554, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 1s 12ms/step - loss: 0.0063 - val_loss: 0.0055
# Epoch 10/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 10: val_loss did not improve from 0.00554
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0079
# Epoch 11/150
# 65/70 [==========================>...] - ETA: 0s - loss: 0.0025
# Epoch 11: val_loss did not improve from 0.00554
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 0.0065
# Epoch 12/150
# 65/70 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 12: val_loss improved from 0.00554 to 0.00421, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 13/150
# 65/70 [==========================>...] - ETA: 0s - loss: 0.0018
# Epoch 13: val_loss improved from 0.00421 to 0.00359, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 14/150
# 66/70 [===========================>..] - ETA: 0s - loss: 8.5928e-04
# Epoch 14: val_loss did not improve from 0.00359
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 0.0060
# Epoch 15/150
# 66/70 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 15: val_loss did not improve from 0.00359
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0031 - val_loss: 0.0139
# Epoch 16/150
# 65/70 [==========================>...] - ETA: 0s - loss: 0.0041
# Epoch 16: val_loss did not improve from 0.00359
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 17/150
# 66/70 [===========================>..] - ETA: 0s - loss: 0.0035
# Epoch 17: val_loss improved from 0.00359 to 0.00295, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 1s 12ms/step - loss: 0.0038 - val_loss: 0.0030
# Epoch 18/150
# 66/70 [===========================>..] - ETA: 0s - loss: 8.9868e-04
# Epoch 18: val_loss improved from 0.00295 to 0.00282, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 19/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 19: val_loss did not improve from 0.00282
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 20/150
# 65/70 [==========================>...] - ETA: 0s - loss: 9.9322e-04
# Epoch 20: val_loss did not improve from 0.00282
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 0.0045
# Epoch 21/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 21: val_loss did not improve from 0.00282
# 70/70 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 22/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 22: val_loss did not improve from 0.00282
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 23/150
# 65/70 [==========================>...] - ETA: 0s - loss: 0.0011
# Epoch 23: val_loss did not improve from 0.00282
# 70/70 [==============================] - 1s 12ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 24/150
# 68/70 [============================>.] - ETA: 0s - loss: 7.4125e-04
# Epoch 24: val_loss did not improve from 0.00282
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 25/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 25: val_loss did not improve from 0.00282
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 0.0030
# Epoch 26/150
# 66/70 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 26: val_loss did not improve from 0.00282
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 27/150
# 65/70 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 27: val_loss improved from 0.00282 to 0.00259, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 28/150
# 67/70 [===========================>..] - ETA: 0s - loss: 7.2947e-04
# Epoch 28: val_loss did not improve from 0.00259
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 0.0028
# Epoch 29/150
# 66/70 [===========================>..] - ETA: 0s - loss: 6.5332e-04
# Epoch 29: val_loss did not improve from 0.00259
# 70/70 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 30/150
# 65/70 [==========================>...] - ETA: 0s - loss: 0.0011
# Epoch 30: val_loss did not improve from 0.00259
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 31/150
# 67/70 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 31: val_loss improved from 0.00259 to 0.00255, saving model to new_crypto_model.hdf5
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 32/150
# 65/70 [==========================>...] - ETA: 0s - loss: 7.0927e-04
# Epoch 32: val_loss did not improve from 0.00255
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 0.0026
# Epoch 33/150
# 68/70 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 33: val_loss did not improve from 0.00255
# 70/70 [==============================] - 1s 12ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 34/150
# 66/70 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 34: val_loss did not improve from 0.00255
# 70/70 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 35/150
# 66/70 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 35: val_loss did not improve from 0.00255
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0067
# Epoch 36/150
# 66/70 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 36: val_loss did not improve from 0.00255
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 37/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 37: val_loss did not improve from 0.00255
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 38/150
# 66/70 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 38: val_loss did not improve from 0.00255
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 39/150
# 68/70 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 39: val_loss did not improve from 0.00255
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 40/150
# 66/70 [===========================>..] - ETA: 0s - loss: 8.7996e-04
# Epoch 40: val_loss did not improve from 0.00255
# 70/70 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 41/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 41: val_loss did not improve from 0.00255
# 70/70 [==============================] - 1s 12ms/step - loss: 0.0033 - val_loss: 0.0032

# %%
## Save LSTM Model
#
from  keras.models import load_model

model_from_saved_checkpoint = load_model(checkpoint_path)

# %%
## Visualise Loss

plt.figure(figsize=(16,7))
plt.plot(history.history['loss'], label='train')

plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# Transformation to original form and making the predictions

predicted_btc_price_test_data = regressor.predict(testX)
# test_predicted = model_from_saved_checkpoint.predict(testing_data_X)

predicted_btc_price_test_data = scaler_test.inverse_transform(predicted_btc_price_test_data.reshape(-1, 1))
test_actual = scaler_test.inverse_transform(testY.reshape(-1, 1))
# Out:
# 18/18 [==============================] - 2s 6ms/step

# %%
test_actual
# Out:
# array([[32569.84960938],
#        [30432.546875  ],
#        [33466.09765625],
#        [34316.38671875],
#        [34269.5234375 ],
#        [33114.359375  ],
#        [33537.17578125],
#        [35510.2890625 ],
#        [37472.08984375],
#        [36926.06640625],
#        [38144.30859375],
#        [39266.01171875],
#        [38903.44140625],
#        [46196.46484375],
#        [46481.10546875],
#        [44918.18359375],
#        [47909.33203125],
#        [47504.8515625 ],
#        [47105.515625  ],
#        [48717.2890625 ],
#        [47945.05859375],
#        [49199.87109375],
#        [52149.0078125 ],
#        [51679.796875  ],
#        [55888.1328125 ],
#        [56099.51953125],
#        [57539.9453125 ],
#        [54207.3203125 ],
#        [48824.42578125],
#        [49705.33203125],
#        [47093.8515625 ],
#        [46339.76171875],
#        [46188.453125  ],
#        [45137.76953125],
#        [49631.2421875 ],
#        [48378.98828125],
#        [50538.2421875 ],
#        [48561.16796875],
#        [48927.3046875 ],
#        [48912.3828125 ],
#        [51206.69140625],
#        [52246.5234375 ],
#        [54824.1171875 ],
#        [56008.55078125],
#        [57805.12109375],
#        [57332.08984375],
#        [61243.0859375 ],
#        [59302.31640625],
#        [55907.19921875],
#        [56804.90234375],
#        [58870.89453125],
#        [57858.921875  ],
#        [58346.65234375],
#        [58313.64453125],
#        [57523.421875  ],
#        [54529.14453125],
#        [54738.9453125 ],
#        [52774.265625  ],
#        [51704.16015625],
#        [55137.3125    ],
#        [55973.51171875],
#        [55950.74609375],
#        [57750.19921875],
#        [58917.69140625],
#        [58918.83203125],
#        [59095.80859375],
#        [59384.3125    ],
#        [57603.890625  ],
#        [58758.5546875 ],
#        [59057.87890625],
#        [58192.359375  ],
#        [56048.9375    ],
#        [58323.953125  ],
#        [58245.00390625],
#        [59793.234375  ],
#        [60204.96484375],
#        [59893.453125  ],
#        [63503.45703125],
#        [63109.6953125 ],
#        [63314.01171875],
#        [61572.7890625 ],
#        [60683.8203125 ],
#        [56216.18359375],
#        [55724.265625  ],
#        [56473.03125   ],
#        [53906.08984375],
#        [51762.2734375 ],
#        [51093.65234375],
#        [50050.8671875 ],
#        [49004.25390625],
#        [54021.75390625],
#        [55033.1171875 ],
#        [54824.703125  ],
#        [53555.109375  ],
#        [57750.17578125],
#        [57828.05078125],
#        [56631.078125  ],
#        [57200.29296875],
#        [53333.5390625 ],
#        [57424.0078125 ],
#        [56396.515625  ],
#        [57356.40234375],
#        [58803.77734375],
#        [58232.31640625],
#        [55859.796875  ],
#        [56704.57421875],
#        [49150.53515625],
#        [49716.19140625],
#        [49880.53515625],
#        [46760.1875    ],
#        [46456.05859375],
#        [43537.51171875],
#        [42909.40234375],
#        [37002.44140625],
#        [40782.73828125],
#        [37304.69140625],
#        [37536.6328125 ],
#        [34770.58203125],
#        [38705.98046875],
#        [38402.22265625],
#        [39294.19921875],
#        [38436.96875   ],
#        [35697.60546875],
#        [34616.06640625],
#        [35678.12890625],
#        [37332.85546875],
#        [36684.92578125],
#        [37575.1796875 ],
#        [39208.765625  ],
#        [36894.40625   ],
#        [35551.95703125],
#        [35862.37890625],
#        [33560.70703125],
#        [33472.6328125 ],
#        [37345.12109375],
#        [36702.59765625],
#        [37334.3984375 ],
#        [35552.515625  ],
#        [39097.859375  ],
#        [40218.4765625 ],
#        [40406.26953125],
#        [38347.0625    ],
#        [38053.50390625],
#        [35787.24609375],
#        [35615.87109375],
#        [35698.296875  ],
#        [31676.69335938],
#        [32505.66015625],
#        [33723.02734375],
#        [34662.4375    ],
#        [31637.77929688],
#        [32186.27734375],
#        [34649.64453125],
#        [34434.3359375 ],
#        [35867.77734375],
#        [35040.8359375 ],
#        [33572.1171875 ],
#        [33897.046875  ],
#        [34668.546875  ],
#        [35287.78125   ],
#        [33746.00390625],
#        [34235.1953125 ],
#        [33855.328125  ],
#        [32877.37109375],
#        [33798.01171875],
#        [33520.51953125],
#        [34240.1875    ],
#        [33155.84765625],
#        [32702.02539062],
#        [32822.34765625],
#        [31780.73046875],
#        [31421.5390625 ],
#        [31533.06835938],
#        [31796.81054688],
#        [30817.83203125],
#        [29807.34765625],
#        [32110.69335938],
#        [32313.10546875],
#        [33581.55078125],
#        [34292.4453125 ],
#        [35350.1875    ],
#        [37337.53515625],
#        [39406.94140625],
#        [39995.90625   ],
#        [40008.421875  ],
#        [42235.546875  ],
#        [41626.1953125 ],
#        [39974.89453125],
#        [39201.9453125 ],
#        [38152.98046875],
#        [39747.50390625],
#        [40869.5546875 ],
#        [42816.5       ],
#        [44555.80078125],
#        [43798.1171875 ],
#        [46365.40234375],
#        [45585.03125   ],
#        [45593.63671875],
#        [44428.2890625 ],
#        [47793.3203125 ],
#        [47096.9453125 ],
#        [47047.00390625],
#        [46004.484375  ],
#        [44695.359375  ],
#        [44801.1875    ],
#        [46717.578125  ],
#        [49339.17578125],
#        [48905.4921875 ],
#        [49321.65234375],
#        [49546.1484375 ],
#        [47706.1171875 ],
#        [48960.7890625 ],
#        [46942.21875   ],
#        [49058.66796875],
#        [48902.40234375],
#        [48829.83203125],
#        [47054.984375  ],
#        [47166.6875    ],
#        [48847.02734375],
#        [49327.72265625],
#        [50025.375     ],
#        [49944.625     ],
#        [51753.41015625],
#        [52633.53515625],
#        [46811.12890625],
#        [46091.390625  ],
#        [46391.421875  ],
#        [44883.91015625],
#        [45201.45703125],
#        [46063.26953125],
#        [44963.07421875],
#        [47092.4921875 ],
#        [48176.34765625],
#        [47783.359375  ],
#        [47267.51953125],
#        [48278.36328125],
#        [47260.21875   ],
#        [42843.80078125],
#        [40693.67578125],
#        [43574.5078125 ],
#        [44895.09765625],
#        [42839.75      ],
#        [42716.59375   ],
#        [43208.5390625 ],
#        [42235.73046875],
#        [41034.54296875],
#        [41564.36328125],
#        [43790.89453125],
#        [48116.94140625],
#        [47711.48828125],
#        [48199.953125  ],
#        [49112.90234375],
#        [51514.8125    ],
#        [55361.44921875],
#        [53805.984375  ],
#        [53967.84765625],
#        [54968.22265625],
#        [54771.578125  ],
#        [57484.7890625 ],
#        [56041.05859375],
#        [57401.09765625],
#        [57321.5234375 ],
#        [61593.94921875],
#        [60892.1796875 ],
#        [61553.6171875 ],
#        [62026.078125  ],
#        [64261.9921875 ],
#        [65992.8359375 ],
#        [62210.171875  ],
#        [60692.265625  ],
#        [61393.6171875 ],
#        [60930.8359375 ],
#        [63039.82421875],
#        [60363.79296875],
#        [58482.38671875],
#        [60622.13671875],
#        [62227.96484375],
#        [61888.83203125],
#        [61318.95703125],
#        [61004.40625   ],
#        [63226.40234375],
#        [62970.046875  ],
#        [61452.23046875],
#        [61125.67578125],
#        [61527.48046875],
#        [63326.98828125],
#        [67566.828125  ],
#        [66971.828125  ],
#        [64995.23046875],
#        [64949.9609375 ],
#        [64155.94140625],
#        [64469.52734375],
#        [65466.83984375],
#        [63557.87109375],
#        [60161.24609375],
#        [60368.01171875],
#        [56942.13671875],
#        [58119.578125  ],
#        [59697.1953125 ],
#        [58730.4765625 ],
#        [56289.2890625 ],
#        [57569.07421875],
#        [56280.42578125],
#        [57274.6796875 ],
#        [53569.765625  ],
#        [54815.078125  ],
#        [57248.45703125],
#        [57806.56640625],
#        [57005.42578125],
#        [57229.828125  ],
#        [56477.81640625],
#        [53598.24609375],
#        [49200.703125  ],
#        [49368.84765625],
#        [50582.625     ],
#        [50700.0859375 ],
#        [50504.796875  ],
#        [47672.12109375],
#        [47243.3046875 ],
#        [49362.5078125 ],
#        [50098.3359375 ],
#        [46737.48046875],
#        [46612.6328125 ],
#        [48896.72265625],
#        [47665.42578125],
#        [46202.14453125],
#        [46848.77734375],
#        [46707.015625  ],
#        [46880.27734375],
#        [48936.61328125],
#        [48628.51171875],
#        [50784.5390625 ],
#        [50822.1953125 ],
#        [50429.859375  ],
#        [50809.515625  ],
#        [50640.41796875],
#        [47588.85546875],
#        [46444.7109375 ],
#        [47178.125     ],
#        [46306.4453125 ],
#        [47686.8125    ],
#        [47345.21875   ],
#        [46458.1171875 ],
#        [45897.57421875],
#        [43569.00390625],
#        [43160.9296875 ],
#        [41557.90234375],
#        [41733.94140625],
#        [41911.6015625 ],
#        [41821.26171875],
#        [42735.85546875],
#        [43949.1015625 ],
#        [42591.5703125 ],
#        [43099.69921875],
#        [43177.3984375 ],
#        [43113.87890625],
#        [42250.55078125],
#        [42375.6328125 ],
#        [41744.328125  ],
#        [40680.41796875],
#        [36457.31640625],
#        [35030.25      ],
#        [36276.8046875 ],
#        [36654.328125  ],
#        [36954.00390625],
#        [36852.12109375],
#        [37138.234375  ],
#        [37784.33203125],
#        [38138.1796875 ],
#        [37917.6015625 ],
#        [38483.125     ],
#        [38743.2734375 ],
#        [36952.984375  ],
#        [37154.6015625 ],
#        [41500.875     ],
#        [41441.1640625 ],
#        [42412.43359375],
#        [43840.28515625],
#        [44118.4453125 ],
#        [44338.796875  ],
#        [43565.11328125],
#        [42407.9375    ],
#        [42244.46875   ],
#        [42197.515625  ],
#        [42586.91796875],
#        [44575.203125  ],
#        [43961.859375  ],
#        [40538.01171875],
#        [40030.9765625 ],
#        [40122.15625   ],
#        [38431.37890625],
#        [37075.28125   ],
#        [38286.02734375],
#        [37296.5703125 ],
#        [38332.609375  ],
#        [39214.21875   ],
#        [39105.1484375 ],
#        [37709.78515625],
#        [43193.234375  ],
#        [44354.63671875],
#        [43924.1171875 ],
#        [42451.7890625 ],
#        [39137.60546875],
#        [39400.5859375 ],
#        [38419.984375  ],
#        [38062.0390625 ],
#        [38737.26953125],
#        [41982.92578125],
#        [39437.4609375 ],
#        [38794.97265625],
#        [38904.01171875],
#        [37849.6640625 ],
#        [39666.75390625],
#        [39338.78515625],
#        [41143.9296875 ],
#        [40951.37890625],
#        [41801.15625   ],
#        [42190.65234375],
#        [41247.82421875],
#        [41077.99609375],
#        [42358.80859375],
#        [42892.95703125],
#        [43960.93359375],
#        [44348.73046875],
#        [44500.828125  ],
#        [46820.4921875 ],
#        [47128.00390625],
#        [47465.73046875],
#        [47062.6640625 ],
#        [45538.67578125],
#        [46281.64453125],
#        [45868.94921875],
#        [46453.56640625],
#        [46622.67578125],
#        [45555.9921875 ],
#        [43206.73828125],
#        [43503.84765625],
#        [42287.6640625 ],
#        [42782.13671875],
#        [42207.671875  ],
#        [39521.90234375],
#        [40127.18359375],
#        [41166.73046875],
#        [39935.515625  ],
#        [40553.46484375],
#        [40424.484375  ],
#        [39716.953125  ],
#        [40826.21484375],
#        [41502.75      ],
#        [41374.37890625],
#        [40527.36328125],
#        [39740.3203125 ],
#        [39486.73046875],
#        [39469.29296875],
#        [40458.30859375],
#        [38117.4609375 ],
#        [39241.12109375],
#        [39773.828125  ],
#        [38609.82421875],
#        [37714.875     ],
#        [38469.09375   ],
#        [38529.328125  ],
#        [37750.453125  ],
#        [39698.37109375],
#        [36575.140625  ],
#        [36040.921875  ],
#        [35501.953125  ],
#        [34059.265625  ],
#        [30296.953125  ],
#        [31022.90625   ],
#        [28936.35546875],
#        [29047.75195313],
#        [29283.10351562],
#        [30101.265625  ],
#        [31305.11328125],
#        [29862.91796875],
#        [30425.85742188],
#        [28720.27148438],
#        [30314.33398438],
#        [29200.74023438],
#        [29432.2265625 ],
#        [30323.72265625],
#        [29098.91015625],
#        [29655.5859375 ],
#        [29562.36132812],
#        [29267.22460938],
#        [28627.57421875],
#        [28814.90039063],
#        [29445.95703125],
#        [31726.390625  ],
#        [31792.31054688],
#        [29799.08007813],
#        [30467.48828125],
#        [29704.390625  ],
#        [29832.9140625 ],
#        [29906.66210938],
#        [31370.671875  ],
#        [31155.47851562],
#        [30214.35546875],
#        [30111.99804688],
#        [29083.8046875 ],
#        [28360.81054688],
#        [26762.6484375 ],
#        [22487.38867188],
#        [22206.79296875],
#        [22572.83984375],
#        [20381.65039062],
#        [20471.48242188],
#        [19017.64257812],
#        [20553.27148438],
#        [20599.53710938],
#        [20710.59765625],
#        [19987.02929688],
#        [21085.87695312],
#        [21231.65625   ],
#        [21502.33789062],
#        [21027.29492188],
#        [20735.47851562],
#        [20280.63476562],
#        [20104.0234375 ],
#        [19784.7265625 ],
#        [19269.3671875 ],
#        [19242.25585938],
#        [19297.07617188],
#        [20231.26171875],
#        [20190.11523438],
#        [20548.24609375],
#        [21637.58789062],
#        [21731.1171875 ],
#        [21592.20703125],
#        [20860.44921875],
#        [19970.55664062],
#        [19323.9140625 ],
#        [20212.07421875],
#        [20569.91992188],
#        [20836.328125  ],
#        [21190.31640625],
#        [20779.34375   ],
#        [22485.68945312],
#        [23389.43359375],
#        [23231.73242188],
#        [23164.62890625],
#        [22714.97851562],
#        [22465.47851562],
#        [22609.1640625 ],
#        [21361.70117188],
#        [21239.75390625],
#        [22930.54882812],
#        [23843.88671875],
#        [23804.6328125 ],
#        [23656.20703125]])

# %%
plt.figure(figsize=(16,7))

plt.plot(predicted_btc_price_test_data, 'r', marker='.', label='Predicted Test')

plt.plot(test_actual, marker='.', label='Actual Test')

plt.legend()
plt.show()

# %%
testX.shape
# Out:
# (551, 3, 1)

# %%
## Future 5 days

testX.shape
look_back = 90
past_days = testX[testX.shape[0] - look_back :]

past_days.shape
past_days

future_days = []
for i in range(89):
    forecast_test_x = model_from_saved_checkpoint.predict(past_days[i:i+1])
    forecast_test_x = scaler_test.inverse_transform(forecast_test_x.reshape(-1,1))
    future_days.append(forecast_test_x)

print ("Forecast:", np.array(future_days))



###Save this to trouble shoot scaled issues having Attribute Error
# future_days = []
# for i in range(5):
#     future_days = model_from_saved_checkpoint.predict(past_5days[i:i+1])
#     # forecast_test_x = scaled_ts.inverse_transform(forecast_test_x.reshape(-1,1))
#     future_days.append(future_days)
#
# print ("Forecast:", np.array(future_days))
# Out:
# 1/1 [==============================] - 1s 782ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Forecast: [[[38419.86 ]]
#
#  [[38067.69 ]]
#
#  [[38487.875]]
#
#  [[38483.64 ]]
#
#  [[38250.133]]
#
#  [[38556.438]]
#
#  [[36442.92 ]]
#
#  [[35842.926]]
#
#  [[34829.816]]
#
#  [[33033.727]]
#
#  [[30728.486]]
#
#  [[30710.762]]
#
#  [[29392.434]]
#
#  [[29573.166]]
#
#  [[29999.188]]
#
#  [[30731.232]]
#
#  [[31220.143]]
#
#  [[30279.453]]
#
#  [[30354.936]]
#
#  [[29541.71 ]]
#
#  [[30334.82 ]]
#
#  [[29721.682]]
#
#  [[29998.633]]
#
#  [[30332.172]]
#
#  [[29657.047]]
#
#  [[29976.486]]
#
#  [[29802.426]]
#
#  [[29475.705]]
#
#  [[29151.277]]
#
#  [[29571.164]]
#
#  [[30529.656]]
#
#  [[31935.852]]
#
#  [[31519.674]]
#
#  [[30314.277]]
#
#  [[30584.16 ]]
#
#  [[30115.256]]
#
#  [[30318.121]]
#
#  [[30707.754]]
#
#  [[31572.457]]
#
#  [[31186.723]]
#
#  [[30462.117]]
#
#  [[30100.432]]
#
#  [[29157.107]]
#
#  [[28079.834]]
#
#  [[26308.97 ]]
#
#  [[23285.719]]
#
#  [[23023.027]]
#
#  [[22386.688]]
#
#  [[20261.615]]
#
#  [[20115.81 ]]
#
#  [[19873.94 ]]
#
#  [[20563.787]]
#
#  [[20551.223]]
#
#  [[20511.387]]
#
#  [[20419.268]]
#
#  [[21415.545]]
#
#  [[21615.746]]
#
#  [[21623.115]]
#
#  [[20961.059]]
#
#  [[20519.885]]
#
#  [[20187.625]]
#
#  [[20016.775]]
#
#  [[19825.566]]
#
#  [[19713.63 ]]
#
#  [[19751.326]]
#
#  [[19863.895]]
#
#  [[20243.188]]
#
#  [[20420.734]]
#
#  [[21132.16 ]]
#
#  [[22204.135]]
#
#  [[22143.057]]
#
#  [[21524.57 ]]
#
#  [[20431.979]]
#
#  [[19945.1  ]]
#
#  [[19893.328]]
#
#  [[20361.293]]
#
#  [[20733.295]]
#
#  [[21062.357]]
#
#  [[21434.188]]
#
#  [[21893.562]]
#
#  [[23697.854]]
#
#  [[24393.201]]
#
#  [[24220.312]]
#
#  [[24025.186]]
#
#  [[23581.162]]
#
#  [[23345.617]]
#
#  [[22989.592]]
#
#  [[21842.518]]
#
#  [[22511.303]]]

# %%
#### Data Visualisations


fig, ax = plt.subplots(1, figsize=(13, 7))

ax.plot(training_data, label='Train', linewidth=2)
ax.plot(testing_data, label='Test', linewidth=2)
ax.set_ylabel('Price USD', fontsize=14)
ax.set_title('BitCoin Closeprice Train-Test Data', fontsize=16)
ax.legend(loc='best', fontsize=16)

# Scaled Data
fig, ax = plt.subplots(1, figsize=(13, 7))

ax.plot(scaled_td, label='Train', linewidth=2)
ax.plot(scaled_ts, label='Test', linewidth=2)
ax.set_ylabel('Price USD', fontsize=14)
ax.set_title('BitCoin Closeprice Train-Test Data', fontsize=16)
ax.legend(loc='best', fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 15>()
#      12 # Scaled Data
#      13 fig, ax = plt.subplots(1, figsize=(13, 7))
# ---> 15 ax.plot(scaled_td, label='Train', linewidth=2)
#      16 ax.plot(scaled_ts, label='Test', linewidth=2)
#      17 ax.set_ylabel('Price USD', fontsize=14)
#
# NameError: name 'scaled_td' is not defined
